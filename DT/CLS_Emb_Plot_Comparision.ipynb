# %%
import matplotlib.pyplot as plt

# %%
# Validation Accuracy
DT_val_acc = [0.4943, 0.5223, 0.5246, 0.5386, 0.5639, 0.5715, 0.5766]
ET_val_acc = [0.5061, 0.5012, 0.5124, 0.5283, 0.5367, 0.5564, 0.5536]
RF_val_acc = [0.5086, 0.5053, 0.5097, 0.5516, 0.5829, 0.5935, 0.5903]
ET_Ensemble_val_acc = [0.5044, 0.5105, 0.5121, 0.5541, 0.5769, 0.5773, 0.585]
n_trainSamples = [100,500,1000,10000,20000,50000,75000]

# %%
def valAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_val_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_val_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_val_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_val_acc,label='ExtraTreeEnsemble')
    plt.title("Validation Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Emb_Val_Accuracy_Comparision.png")
    #plt.show()

# %%
valAccuracyVisualization()

# %%
# Test Accuracy
DT_test_acc = [0.494, 0.51, 0.5197, 0.5397, 0.5597, 0.5665, 0.568]
ET_test_acc = [0.4996, 0.5047, 0.5097, 0.5219, 0.5342, 0.5593, 0.5516]
RF_test_acc = [0.5147, 0.5105, 0.5109, 0.5419, 0.5954, 0.5871, 0.5921]
ET_Ensemble_test_acc = [0.5006, 0.5121, 0.5171, 0.5482, 0.5599, 0.5865, 0.5832]

# %%
def testAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_test_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_test_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_test_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_test_acc,label='ExtraTreeEnsemble')
    plt.title("Test Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Tokens_Test_Accuracy_Comparision.png")
    #plt.show()

# %%
testAccuracyVisualization()

# %%
mrrScore_DT =[(0.3056746031746, 0.019333333333333334, 0.104), (0.3460654160654147, 0.034, 0.3913333333333333), (0.37953328523328433, 0.08333333333333333, 0.44533333333333336), (0.43130004810004696, 0.13933333333333334, 0.5446666666666666), (0.42764280904280855, 0.13333333333333333, 0.5473333333333333), (0.4493439153439141, 0.15333333333333332, 0.578), (0.45552587782587617, 0.16666666666666666, 0.5866666666666667)]
mrrScore_ET = [(0.3183339105339078, 0.03133333333333333, 0.144), (0.3501596921596912, 0.07133333333333333, 0.23533333333333334), (0.36853828763828717, 0.09066666666666667, 0.33), (0.4099685425685412, 0.146, 0.4766666666666667), (0.41768321308321293, 0.142, 0.512), (0.44870899470899434, 0.17466666666666666, 0.5693333333333334), (0.44610519480519406, 0.16466666666666666, 0.57)]
mrrScore_RF = [(0.4254884559884557, 0.16266666666666665, 0.52), (0.4412291486291489, 0.19933333333333333, 0.556), (0.44806031746031777, 0.214, 0.5366666666666666), (0.4857904761904773, 0.23933333333333334, 0.6313333333333333), (0.5164238095238113, 0.2806666666666667, 0.6706666666666666), (0.5307666666666685, 0.29133333333333333, 0.6953333333333334), (0.5292222222222241, 0.2906666666666667, 0.6973333333333334)]
mrrScore_ET_Ensemble = [(0.4176262145262148, 0.168, 0.516), (0.43127311207311325, 0.188, 0.5373333333333333), (0.4583335738335748, 0.228, 0.57), (0.4945333333333346, 0.254, 0.6353333333333333), (0.49404444444444645, 0.26, 0.63), (0.5182777777777802, 0.2753333333333333, 0.6986666666666667), (0.5193444444444472, 0.2826666666666667, 0.6713333333333333)]

mrr_DT = []
mrr_ET = []
mrr_RF = []
mrr_ET_Ensemble = []

p1_DT = []
p1_ET = []
p1_RF = []
p1_ET_Ensemble = []

p3_DT = []
p3_ET = []
p3_RF = []
p3_ET_Ensemble = []

for itm in mrrScore_DT:
    mrr_DT.append(itm[0])
    p1_DT.append(itm[1])
    p3_DT.append(itm[2])

for itm in mrrScore_ET:
    mrr_ET.append(itm[0])
    p1_ET.append(itm[1])
    p3_ET.append(itm[2])

for itm in mrrScore_RF:
    mrr_RF.append(itm[0])
    p1_RF.append(itm[1])
    p3_RF.append(itm[2])
    
for itm in mrrScore_ET_Ensemble:
    mrr_ET_Ensemble.append(itm[0])
    p1_ET_Ensemble.append(itm[1])
    p3_ET_Ensemble.append(itm[2])

# %%
# Mrr Comparision
def mrrAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,mrr_DT,label='DecisionTree')
    ax.plot(n_trainSamples,mrr_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,mrr_RF,label='RandomForest')
    ax.plot(n_trainSamples,mrr_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("Mrr Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Tokens_MRR_Scores_Comparision.png")
    #plt.show()

# %%
mrrAccuracyVisualization()

# %%
# PR@1 Comparision
def pr1AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p1_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p1_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p1_RF,label='RandomForest')
    ax.plot(n_trainSamples,p1_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr1 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Tokens_pr1_Scores_Comparision.png")
    #plt.show(

# %%
pr1AccuracyVisualization()

# %%
# PR@3 Comparision
def pr3AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p3_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p3_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p3_RF,label='RandomForest')
    ax.plot(n_trainSamples,p3_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr3 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Tokens_pr3_Scores_Comparision.png")
    #plt.show(

# %%
pr3AccuracyVisualization()
