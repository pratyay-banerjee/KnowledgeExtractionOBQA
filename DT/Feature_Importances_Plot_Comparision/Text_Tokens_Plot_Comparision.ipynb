# %%
import matplotlib.pyplot as plt

# %%
# Validation Accuracy
DT_val_acc = [0.5051, 0.4967, 0.507, 0.5467, 0.5654, 0.5661, 0.5618]
ET_val_acc = [0.5044, 0.504, 0.5068, 0.5393, 0.5365, 0.5431, 0.5325]
RF_val_acc = [0.5003, 0.4929, 0.5146, 0.5425, 0.5517, 0.5605, 0.57]
ET_Ensemble_val_acc = [0.5, 0.5033, 0.5081, 0.5463, 0.5565, 0.5761, 0.5753]
n_trainSamples = [100,500,1000,10000,20000,50000,75000]

# %%
def valAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_val_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_val_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_val_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_val_acc,label='ExtraTreeEnsemble')
    plt.title("Validation Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("Text_Tokens_Val_Accuracy_Comparision.png")
    #plt.show()

# %%
valAccuracyVisualization()

# %%
# Test Accuracy
DT_test_acc = [0.5015, 0.4987, 0.5003, 0.5369, 0.549, 0.5493, 0.5573]
ET_test_acc = [0.5001, 0.5063, 0.5068, 0.5321, 0.5441, 0.5304, 0.5259]
RF_test_acc = [0.5003, 0.4929, 0.5146, 0.5425, 0.5517, 0.5605, 0.57]
ET_Ensemble_test_acc = [0.5, 0.5058, 0.5106, 0.5339, 0.5547, 0.5517, 0.5706]

# %%
def testAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_test_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_test_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_test_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_test_acc,label='ExtraTreeEnsemble')
    plt.title("Test Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("Text_Tokens_Test_Accuracy_Comparision.png")
    #plt.show()

# %%
testAccuracyVisualization()

# %%
mrrScore_DT =[(0.34271289081288925, 0.068, 0.19333333333333333), (0.3435213564213547, 0.046, 0.2906666666666667), (0.34467806637806536, 0.03133333333333333, 0.3453333333333333), (0.41869557479557307, 0.12933333333333333, 0.5353333333333333), (0.42160885040884916, 0.13333333333333333, 0.5186666666666667), (0.43584526214526187, 0.14866666666666667, 0.5246666666666666), (0.435964502164501, 0.15, 0.5393333333333333)]
mrrScore_ET = [(0.31500663780663496, 0.03933333333333333, 0.07933333333333334), (0.31911491101490735, 0.05, 0.07333333333333333), (0.3447943722943697, 0.056, 0.43733333333333335), (0.3668585377585358, 0.064, 0.51), (0.4225957190957182, 0.14266666666666666, 0.51), (0.4012901875901865, 0.12533333333333332, 0.4666666666666667), (0.39411875901875804, 0.11933333333333333, 0.4866666666666667)]
mrrScore_RF = [(0.4017552188552172, 0.13866666666666666, 0.4826666666666667), (0.3950928330928335, 0.14066666666666666, 0.4746666666666667), (0.4274217412217425, 0.18133333333333335, 0.5066666666666667), (0.445569312169313, 0.18866666666666668, 0.572), (0.4649688792688787, 0.204, 0.58), (0.4744882154882158, 0.22133333333333333, 0.5993333333333334), (0.4768623857623865, 0.222, 0.602)]
mrrScore_ET_Ensemble = [(0.35788734968734964, 0.08866666666666667, 0.2613333333333333), (0.42621904761904733, 0.178, 0.5006666666666667), (0.432071188071188, 0.176, 0.5346666666666666), (0.4625231842231846, 0.20666666666666667, 0.5766666666666667), (0.4690254930254928, 0.21466666666666667, 0.582), (0.4823238576238588, 0.24333333333333335, 0.5846666666666667), (0.4838741221741232, 0.24066666666666667, 0.6126666666666667)]

mrr_DT = []
mrr_ET = []
mrr_RF = []
mrr_ET_Ensemble = []

p1_DT = []
p1_ET = []
p1_RF = []
p1_ET_Ensemble = []

p3_DT = []
p3_ET = []
p3_RF = []
p3_ET_Ensemble = []

for itm in mrrScore_DT:
    mrr_DT.append(itm[0])
    p1_DT.append(itm[1])
    p3_DT.append(itm[2])

for itm in mrrScore_ET:
    mrr_ET.append(itm[0])
    p1_ET.append(itm[1])
    p3_ET.append(itm[2])

for itm in mrrScore_RF:
    mrr_RF.append(itm[0])
    p1_RF.append(itm[1])
    p3_RF.append(itm[2])
    
for itm in mrrScore_ET_Ensemble:
    mrr_ET_Ensemble.append(itm[0])
    p1_ET_Ensemble.append(itm[1])
    p3_ET_Ensemble.append(itm[2])

# %%
# Mrr Comparision
def mrrAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,mrr_DT,label='DecisionTree')
    ax.plot(n_trainSamples,mrr_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,mrr_RF,label='RandomForest')
    ax.plot(n_trainSamples,mrr_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("Mrr Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("Text_Tokens_MRR_Scores_Comparision.png")
    #plt.show()

# %%
mrrAccuracyVisualization()

# %%
# PR@1 Comparision
def pr1AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p1_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p1_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p1_RF,label='RandomForest')
    ax.plot(n_trainSamples,p1_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr1 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("Text_Tokens_pr1_Scores_Comparision.png")
    #plt.show(

# %%
pr1AccuracyVisualization()

# %%
# PR@3 Comparision
def pr3AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p3_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p3_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p3_RF,label='RandomForest')
    ax.plot(n_trainSamples,p3_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr3 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("Text_Tokens_pr3_Scores_Comparision.png")
    #plt.show(

# %%
pr3AccuracyVisualization()
