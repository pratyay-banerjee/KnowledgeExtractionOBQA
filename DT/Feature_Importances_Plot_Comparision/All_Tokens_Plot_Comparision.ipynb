# %%
import matplotlib.pyplot as plt

# %%
# Validation Accuracy
DT_val_acc = [0.5046, 0.4985, 0.507, 0.5339, 0.5581, 0.5615, 0.5584]
ET_val_acc = [0.4939, 0.5042, 0.5015, 0.5204, 0.5318, 0.5523, 0.5439]
RF_val_acc = [0.4993, 0.5022, 0.5039, 0.5553, 0.5783, 0.5877, 0.5876]
ET_Ensemble_val_acc = [0.4995, 0.5065, 0.5081, 0.5353, 0.5594, 0.569, 0.5774]
n_trainSamples = [100,500,1000,10000,20000,50000,75000]

# %%
def valAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_val_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_val_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_val_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_val_acc,label='ExtraTreeEnsemble')
    plt.title("Validation Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_Tokens_Val_Accuracy_Comparision.png")
    #plt.show()

# %%
valAccuracyVisualization()

# %%
# Test Accuracy
DT_test_acc = [0.5041, 0.4939, 0.4964, 0.5285, 0.5524, 0.5669, 0.5568]
ET_test_acc = [0.497, 0.5045, 0.5121, 0.5134, 0.5131, 0.5569, 0.536]
RF_test_acc = [0.5035, 0.5027, 0.4977, 0.5475, 0.5603, 0.5741, 0.5788]
ET_Ensemble_test_acc = [0.4995, 0.509, 0.5049, 0.538, 0.5457, 0.5731, 0.5674]

# %%
def testAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_test_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_test_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_test_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_test_acc,label='ExtraTreeEnsemble')
    plt.title("Test Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_Tokens_Test_Accuracy_Comparision.png")
    #plt.show()

# %%
testAccuracyVisualization()

# %%
mrrScore_DT = [(0.3522770081770077, 0.06533333333333333, 0.236), (0.34386931216931105, 0.07533333333333334, 0.18333333333333332), (0.35524001924001863, 0.07266666666666667, 0.2713333333333333), (0.4182093795093787, 0.13133333333333333, 0.5273333333333333), (0.43038080808080764, 0.13266666666666665, 0.56), (0.45731962481962385, 0.176, 0.5833333333333334), (0.4611036075036066, 0.18333333333333332, 0.5826666666666667)]
mrrScore_ET = [(0.35615714285714245, 0.08666666666666667, 0.23133333333333334), (0.3836341510341498, 0.114, 0.4073333333333333), (0.3884449735449726, 0.094, 0.4653333333333333), (0.39322053872053775, 0.09666666666666666, 0.486), (0.400091967291966, 0.11733333333333333, 0.49333333333333335), (0.4268695045695036, 0.15066666666666667, 0.516), (0.40922029822029676, 0.126, 0.4573333333333333)]
mrrScore_RF = [(0.39614737854737747, 0.118, 0.4653333333333333), (0.42281813371813365, 0.17866666666666667, 0.5186666666666667), (0.41224444444444436, 0.16866666666666666, 0.508), (0.4764878787878796, 0.23666666666666666, 0.6066666666666667), (0.48385772005772143, 0.242, 0.6286666666666667), (0.5102894660894676, 0.2753333333333333, 0.65), (0.5313962962962976, 0.29533333333333334, 0.69)]
mrrScore_ET_Ensemble = [(0.43575257335257256, 0.19533333333333333, 0.5133333333333333), (0.4290810485810491, 0.184, 0.5393333333333333), (0.4212756613756615, 0.184, 0.5133333333333333), (0.4751979797979803, 0.236, 0.606), (0.48568518518518633, 0.25066666666666665, 0.6026666666666667), (0.49994444444444675, 0.26066666666666666, 0.6486666666666666), (0.5080313131313139, 0.26866666666666666, 0.6526666666666666)]

mrr_DT = []
mrr_ET = []
mrr_RF = []
mrr_ET_Ensemble = []

p1_DT = []
p1_ET = []
p1_RF = []
p1_ET_Ensemble = []

p3_DT = []
p3_ET = []
p3_RF = []
p3_ET_Ensemble = []

for itm in mrrScore_DT:
    mrr_DT.append(itm[0])
    p1_DT.append(itm[1])
    p3_DT.append(itm[2])

for itm in mrrScore_ET:
    mrr_ET.append(itm[0])
    p1_ET.append(itm[1])
    p3_ET.append(itm[2])

for itm in mrrScore_RF:
    mrr_RF.append(itm[0])
    p1_RF.append(itm[1])
    p3_RF.append(itm[2])
    
for itm in mrrScore_ET_Ensemble:
    mrr_ET_Ensemble.append(itm[0])
    p1_ET_Ensemble.append(itm[1])
    p3_ET_Ensemble.append(itm[2])

# %%
# Mrr Comparision
def mrrAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,mrr_DT,label='DecisionTree')
    ax.plot(n_trainSamples,mrr_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,mrr_RF,label='RandomForest')
    ax.plot(n_trainSamples,mrr_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("Mrr Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_Tokens_MRR_Scores_Comparision.png")
    #plt.show()

# %%
mrrAccuracyVisualization()

# %%
# PR@1 Comparision
def pr1AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p1_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p1_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p1_RF,label='RandomForest')
    ax.plot(n_trainSamples,p1_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr1 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_Tokens_pr1_Scores_Comparision.png")
    #plt.show(

# %%
pr1AccuracyVisualization()

# %%
# PR@3 Comparision
def pr3AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p3_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p3_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p3_RF,label='RandomForest')
    ax.plot(n_trainSamples,p3_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr3 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_Tokens_pr3_Scores_Comparision.png")
    #plt.show(

# %%
pr3AccuracyVisualization()
