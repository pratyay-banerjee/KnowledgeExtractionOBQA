# %%
import matplotlib.pyplot as plt

# %%
# Validation Accuracy
DT_val_acc = [0.5087, 0.5029, 0.4994, 0.5243, 0.5445, 0.5545, 0.5564]
ET_val_acc = [0.5025, 0.5078, 0.5007, 0.5075, 0.5031, 0.5166, 0.5101]
RF_val_acc = [0.5013, 0.4999, 0.5037, 0.5111, 0.5203, 0.5176, 0.5259]
ET_Ensemble_val_acc = [0.4995, 0.4998, 0.5012, 0.5013, 0.5109, 0.5102, 0.5053]
n_trainSamples = [100,500,1000,10000,20000,50000,75000]

# %%
def valAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_val_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_val_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_val_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_val_acc,label='ExtraTreeEnsemble')
    plt.title("Validation Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_PCA_Tokens_Val_Accuracy_Comparision.png")
    #plt.show()

# %%
valAccuracyVisualization()

# %%
# Test Accuracy
DT_test_acc = [0.5027, 0.5067, 0.5084, 0.5294, 0.5376, 0.5556, 0.5593]
ET_test_acc =[0.5075, 0.5051, 0.4999, 0.5009, 0.5039, 0.5127, 0.5025]
RF_test_acc = [0.4981, 0.5011, 0.4972, 0.5051, 0.5097, 0.5152, 0.5224]
ET_Ensemble_test_acc =[0.5008, 0.4988, 0.4974, 0.5037, 0.5036, 0.5097, 0.5021]

# %%
def testAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,DT_test_acc,label='DecisionTree')
    ax.plot(n_trainSamples,ET_test_acc,label='ExtraTrees')
    ax.plot(n_trainSamples,RF_test_acc,label='RandomForest')
    ax.plot(n_trainSamples,ET_Ensemble_test_acc,label='ExtraTreeEnsemble')
    plt.title("Test Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_PCA_Tokens_Test_Accuracy_Comparision.png")
    #plt.show()

# %%
testAccuracyVisualization()

# %%
mrrScore_DT = [(0.3327637806637786, 0.06266666666666666, 0.124), (0.3452365079365067, 0.08133333333333333, 0.14933333333333335), (0.3760293891293884, 0.10066666666666667, 0.42866666666666664), (0.3831247234247215, 0.086, 0.5006666666666667), (0.40736382876382676, 0.11733333333333333, 0.5313333333333333), (0.435816546416544, 0.132, 0.5666666666666667), (0.4412522366522349, 0.14466666666666667, 0.5573333333333333)]
mrrScore_ET = [(0.33532385762385547, 0.062, 0.13066666666666665), (0.334213852813851, 0.056, 0.13066666666666665), (0.34152607022606896, 0.07333333333333333, 0.156), (0.3892409331409324, 0.12933333333333333, 0.44), (0.37590933140933014, 0.11866666666666667, 0.4073333333333333), (0.39713352573352456, 0.144, 0.43266666666666664), (0.3928292448292439, 0.13733333333333334, 0.44)]
mrrScore_RF = [(0.39291048581048493, 0.11333333333333333, 0.4573333333333333), (0.4161958633958637, 0.17866666666666667, 0.49333333333333335), (0.40490370370370293, 0.164, 0.49066666666666664), (0.40748581048581006, 0.16533333333333333, 0.48133333333333334), (0.40869951899951906, 0.162, 0.49666666666666665), (0.42429528619528606, 0.18333333333333332, 0.5066666666666667), (0.41962212602212556, 0.182, 0.502)]
mrrScore_ET_Ensemble = [(0.40061159211159075, 0.14333333333333334, 0.48333333333333334), (0.4162504088504093, 0.17533333333333334, 0.5013333333333333), (0.4006904761904758, 0.16, 0.48533333333333334), (0.40264814814814753, 0.16133333333333333, 0.488), (0.3995122174122171, 0.16, 0.48), (0.40481712361712335, 0.164, 0.48533333333333334), (0.40951861471861456, 0.16133333333333333, 0.506)]

mrr_DT = []
mrr_ET = []
mrr_RF = []
mrr_ET_Ensemble = []

p1_DT = []
p1_ET = []
p1_RF = []
p1_ET_Ensemble = []

p3_DT = []
p3_ET = []
p3_RF = []
p3_ET_Ensemble = []

for itm in mrrScore_DT:
    mrr_DT.append(itm[0])
    p1_DT.append(itm[1])
    p3_DT.append(itm[2])

for itm in mrrScore_ET:
    mrr_ET.append(itm[0])
    p1_ET.append(itm[1])
    p3_ET.append(itm[2])

for itm in mrrScore_RF:
    mrr_RF.append(itm[0])
    p1_RF.append(itm[1])
    p3_RF.append(itm[2])
    
for itm in mrrScore_ET_Ensemble:
    mrr_ET_Ensemble.append(itm[0])
    p1_ET_Ensemble.append(itm[1])
    p3_ET_Ensemble.append(itm[2])

# %%
# Mrr Comparision
def mrrAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,mrr_DT,label='DecisionTree')
    ax.plot(n_trainSamples,mrr_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,mrr_RF,label='RandomForest')
    ax.plot(n_trainSamples,mrr_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("Mrr Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_PCA_Tokens_MRR_Scores_Comparision.png")
    #plt.show()

# %%
mrrAccuracyVisualization()

# %%
# PR@1 Comparision
def pr1AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p1_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p1_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p1_RF,label='RandomForest')
    ax.plot(n_trainSamples,p1_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr1 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_PCA_Tokens_pr1_Scores_Comparision.png")
    #plt.show(

# %%
pr1AccuracyVisualization()

# %%
# PR@3 Comparision
def pr3AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p3_DT,label='DecisionTree')
    ax.plot(n_trainSamples,p3_ET,label='ExtraTrees')
    ax.plot(n_trainSamples,p3_RF,label='RandomForest')
    ax.plot(n_trainSamples,p3_ET_Ensemble,label='ExtraTreeEnsemble')
    plt.title("pr3 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("All_PCA_pr3_Scores_Comparision.png")
    #plt.show(

# %%
pr3AccuracyVisualization()
