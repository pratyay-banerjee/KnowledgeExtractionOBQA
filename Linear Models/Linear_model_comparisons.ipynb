# %%
import matplotlib.pyplot as plt
n_trainSamples = [100,500,1000,10000,20000,50000,75000]

# %%
def visualization(arg1,arg2,arg3,arg4,title,figName):
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,arg1,label='Logistic Regression')
    ax.plot(n_trainSamples,arg2,label='Passive Agressive Classifier')
    ax.plot(n_trainSamples,arg3,label='SGD Classifier')
    ax.plot(n_trainSamples,arg4,label='Perceptron')
    plt.title(title)
    plt.legend()
    plt.xlabel('Train Data')
    plt.ylabel('Scores')
    fig.savefig(figName)

# %% [markdown]
# Fetching the plot values from previously performed datasets:
#
# 1. CLS Tokens

# %%
#Validation Accuracy values
valAccuracy_LogReg = [0.5138, 0.5457, 0.5673, 0.6165, 0.6358, 0.6385, 0.6472]
valAccuracy_PasAgr = [0.5195, 0.5341, 0.5657, 0.6103, 0.6233, 0.6348, 0.6393]
valAccuracy_SGDCla = [0.5033, 0.5258, 0.5465, 0.6081, 0.6242, 0.6303, 0.6469]
valAccuracy_Percep = [0.5205, 0.5525, 0.5558, 0.6102, 0.6251, 0.6317, 0.6429]

visualization(valAccuracy_LogReg,valAccuracy_PasAgr,valAccuracy_SGDCla,valAccuracy_Percep,
              "Validation Accuracy Scores CLS Vs Training Data", "ValAccuracy (CLS) Comparison LinearModel.png")

#Test Accuracy values
testAccuracy_LogReg = [0.5123, 0.5397, 0.5654, 0.6211, 0.6305, 0.6419, 0.6511]
testAccuracy_PasAgr = [0.5247, 0.5391, 0.5643, 0.6091, 0.6253, 0.6376, 0.6425]
testAccuracy_SGDCla = [0.5011, 0.5271, 0.5571, 0.6025, 0.6243, 0.6185, 0.6427]
testAccuracy_Percep = [0.5218, 0.5431, 0.5549, 0.6114, 0.6327, 0.6415, 0.6507]

visualization(testAccuracy_LogReg,testAccuracy_PasAgr,testAccuracy_SGDCla,testAccuracy_Percep,
              "Test Accuracy Scores CLS Vs Training Data", "TestAccuracy (CLS) Comparison LinearModel.png")

#MRR Scores
mrr_LogReg = [0.47543333333333476, 0.49523703703703864, 0.5216111111111136, 0.5725888888888917, 0.5887444444444466, 0.5953222222222243, 0.6008666666666689]
mrr_PasAgr = [0.462100000000002, 0.47274814814814947, 0.4971333333333346, 0.5539111111111131, 0.5813111111111128, 0.5912777777777801, 0.5971000000000024]
mrr_SGDCla = [0.46864444444444614, 0.46314444444444536, 0.49328888888889066, 0.5444777777777798, 0.5816111111111134, 0.5958333333333351, 0.6009222222222241]
mrr_Percep = [0.4730000000000013, 0.4823148148148169, 0.4779460317460327, 0.5512000000000026, 0.5831555555555584, 0.5878222222222247, 0.5967888888888915]

visualization(mrr_LogReg,mrr_PasAgr,mrr_SGDCla,mrr_Percep,
              "MRR Scores CLS Vs Training Data", "MRR (CLS) Comparison LinearModel.png")

#Precision@1 Accuracy
pres1_LogReg = [0.232, 0.252, 0.2866666666666667, 0.342, 0.36533333333333334, 0.37133333333333335, 0.376]
pres1_PasAgr = [0.21933333333333332, 0.232, 0.256, 0.31666666666666665, 0.3566666666666667, 0.37, 0.37133333333333335]
pres1_SGDCla = [0.22, 0.22133333333333333, 0.25066666666666665, 0.30533333333333335, 0.35333333333333333, 0.37466666666666665, 0.37666666666666665]
pres1_Percep = [0.22733333333333333, 0.234, 0.234, 0.31133333333333335, 0.3586666666666667, 0.36333333333333334, 0.37133333333333335]

visualization(pres1_LogReg,pres1_PasAgr,pres1_SGDCla,pres1_Percep,
              "Precision 1 Scores CLS Vs Training Data", "Precision1 (CLS) Comparison LinearModel.png")

#Precision@3 Accuracy
pres3_LogReg = [0.6213333333333333, 0.646, 0.6813333333333333, 0.758, 0.764, 0.7733333333333333, 0.7773333333333333]
pres3_PasAgr = [0.5986666666666667, 0.604, 0.644, 0.7306666666666667, 0.754, 0.7693333333333333, 0.7813333333333333]
pres3_SGDCla = [0.6226666666666667, 0.5833333333333334, 0.6426666666666667, 0.7213333333333334, 0.7573333333333333, 0.7726666666666666, 0.7733333333333333]
pres3_Percep = [0.62, 0.6306666666666667, 0.62, 0.732, 0.7606666666666667, 0.7673333333333333, 0.778]

visualization(pres3_LogReg,pres3_PasAgr,pres3_SGDCla,pres3_Percep,
              "Precision 3 Scores CLS Vs Training Data", "Precision3 (CLS) Comparison LinearModel.png")

# %% [markdown]
# 2. Tokens

# %%
#Validation Accuracy values
valAccuracy_tokens_LogReg = [0.4959, 0.5014, 0.5059, 0.5681, 0.5883, 0.5926, 0.6031]
valAccuracy_tokens_PasAgr = [0.4865, 0.5192, 0.5299, 0.569, 0.5875, 0.5935, 0.6063]
valAccuracy_tokens_SGDCla = [0.5, 0.5, 0.5026, 0.5629, 0.5829, 0.5947, 0.6069]
valAccuracy_tokens_Percep = [0.4961, 0.5229, 0.5231, 0.5436, 0.5573, 0.5722, 0.5871]

visualization(valAccuracy_tokens_LogReg,valAccuracy_tokens_PasAgr,valAccuracy_tokens_SGDCla,valAccuracy_tokens_Percep,
              "Validation Accuracy Scores Tokens Vs Training Data", "ValAccuracy (Tokens) Comparison LinearModel.png")

#Test Accuracy values
testAccuracy_tokens_LogReg = [0.5, 0.5023, 0.5043, 0.5717, 0.5827, 0.5909, 0.5936]
testAccuracy_tokens_PasAgr = [0.4855, 0.5191, 0.5307, 0.5666, 0.5771, 0.5897, 0.5917]
testAccuracy_tokens_SGDCla = [0.4999, 0.5014, 0.5029, 0.5578, 0.5764, 0.5899, 0.5939]
testAccuracy_tokens_Percep = [0.5029, 0.5224, 0.5243, 0.5484, 0.5485, 0.561, 0.5729]

visualization(testAccuracy_tokens_LogReg,testAccuracy_tokens_PasAgr,testAccuracy_tokens_SGDCla,testAccuracy_tokens_Percep,
              "Test Accuracy Scores Tokens Vs Training Data", "TestAccuracy (Tokens) Comparison LinearModel.png")

#MRR Scores
mrr_tokens_LogReg = [0.42562380952381035, 0.4368000000000015, 0.4528222222222227, 0.5088888888888896, 0.515011111111113, 0.523301587301589, 0.5208888888888904]
mrr_tokens_PasAgr = [0.3850329966329959, 0.4339888888888901, 0.4519333333333339, 0.495955555555556, 0.5036555555555566, 0.5127571428571447, 0.5160222222222234]
mrr_tokens_SGDCla = [0.43212380952380924, 0.4404777777777791, 0.45157777777777874, 0.5075444444444466, 0.5122333333333352, 0.5223793650793664, 0.5208333333333353]
mrr_tokens_Percep = [0.40629316979316993, 0.4500555555555569, 0.4458904761904769, 0.4701444444444458, 0.4772222222222236, 0.4882698412698425, 0.48942380952381076]

visualization(mrr_tokens_LogReg,mrr_tokens_PasAgr,mrr_tokens_SGDCla,mrr_tokens_Percep,
              "MRR Scores Tokens Vs Training Data", "MRR (Tokens) Comparison LinearModel.png")

#Precision@1 Accuracy
pres1_tokens_LogReg = [0.18666666666666668, 0.19266666666666668, 0.214, 0.27466666666666667, 0.28, 0.2866666666666667, 0.2806666666666667]
pres1_tokens_PasAgr = [0.13733333333333334, 0.18866666666666668, 0.21466666666666667, 0.2633333333333333, 0.2693333333333333, 0.2753333333333333, 0.2786666666666667]
pres1_tokens_SGDCla = [0.19266666666666668, 0.19466666666666665, 0.21533333333333332, 0.2806666666666667, 0.27666666666666667, 0.2826666666666667, 0.2793333333333333]
pres1_tokens_Percep = [0.174, 0.20733333333333334, 0.208, 0.23533333333333334, 0.242, 0.25333333333333335, 0.25133333333333335]

visualization(pres1_tokens_LogReg,pres1_tokens_PasAgr,pres1_tokens_SGDCla,pres1_tokens_Percep,
              "Precision 1 Scores Tokens Vs Training Data", "Precision1 (Tokens) Comparison LinearModel.png")

#Precision@3 Accuracy
pres3_tokens_LogReg = [0.526, 0.55, 0.5726666666666667, 0.6533333333333333, 0.672, 0.6853333333333333, 0.6786666666666666]
pres3_tokens_PasAgr = [0.472, 0.5493333333333333, 0.5673333333333334, 0.6326666666666667, 0.652, 0.6573333333333333, 0.6646666666666666]
pres3_tokens_SGDCla = [0.5353333333333333, 0.5613333333333334, 0.5606666666666666, 0.632, 0.6686666666666666, 0.6813333333333333, 0.6833333333333333]
pres3_tokens_Percep = [0.4686666666666667, 0.5693333333333334, 0.5526666666666666, 0.5946666666666667, 0.6, 0.6233333333333333, 0.6253333333333333]

visualization(pres3_tokens_LogReg,pres3_tokens_PasAgr,pres3_tokens_SGDCla,pres3_tokens_Percep,
              "Precision 3 Scores Tokens Vs Training Data", "Precision3 (Tokens) Comparison LinearModel.png")

# %% [markdown]
# 3. PCA_ALL

# %%
#Validation Accuracy values
valAccuracy_all_pca_LogReg = [0.5584, 0.5643, 0.5622, 0.5958, 0.6178, 0.6398, 0.6449]
valAccuracy_all_pca_PasAgr = [0.5528, 0.565, 0.5413, 0.5904, 0.6063, 0.6147, 0.6302]
valAccuracy_all_pca_SGDCla = [0.5, 0.5007, 0.4995, 0.5465, 0.5849, 0.6247, 0.6429]
valAccuracy_all_pca_Percep = [0.5281, 0.5233, 0.5, 0.5789, 0.6002, 0.6191, 0.61]

visualization(valAccuracy_all_pca_LogReg,valAccuracy_all_pca_PasAgr,valAccuracy_all_pca_SGDCla,valAccuracy_all_pca_Percep,
              "Validation Accuracy Scores All PCA Vs Training Data", "ValAccuracy (All PCA) Comparison LinearModel.png")

#Test Accuracy values
testAccuracy_all_pca_LogReg = [0.5523, 0.5552, 0.5662, 0.5908, 0.6132, 0.6238, 0.6469]
testAccuracy_all_pca_PasAgr = [0.5483, 0.5612, 0.5527, 0.5897, 0.6135, 0.6079, 0.6295]
testAccuracy_all_pca_SGDCla = [0.5, 0.5, 0.5015, 0.5326, 0.5681, 0.6133, 0.6453]
testAccuracy_all_pca_Percep = [0.5247, 0.5142, 0.5, 0.5719, 0.5985, 0.6173, 0.6111]

visualization(testAccuracy_all_pca_LogReg,testAccuracy_all_pca_PasAgr,testAccuracy_all_pca_SGDCla,testAccuracy_all_pca_Percep,
              "Test Accuracy Scores All PCA Vs Training Data", "TestAccuracy (All PCA) Comparison LinearModel.png")

#MRR Scores
mrr_all_pca_LogReg = [0.4790777777777793, 0.4928555555555578, 0.5027222222222243, 0.5390148148148172, 0.5550126984127005, 0.5808814814814837, 0.5987148148148176]
mrr_all_pca_PasAgr = [0.4654592592592617, 0.4873666666666686, 0.4795460317460329, 0.5391481481481496, 0.5455555555555572, 0.5460222222222241, 0.5707571428571455]
mrr_all_pca_SGDCla = [0.4573904761904774, 0.43184444444444464, 0.438711111111111, 0.5168592592592609, 0.5315238095238114, 0.5717703703703724, 0.5971925925925942]
mrr_all_pca_Percep = [0.4362814814814816, 0.44201269841269875, 0.2857142857142808, 0.528325925925928, 0.538281481481483, 0.5523904761904784, 0.5557571428571451]

visualization(mrr_all_pca_LogReg,mrr_all_pca_PasAgr,mrr_all_pca_SGDCla,mrr_all_pca_Percep,
              "MRR Scores All PCA Vs Training Data", "MRR (All PCA) Comparison LinearModel.png")

#Precision@1 Accuracy
pres1_all_pca_LogReg = [0.246, 0.25533333333333336, 0.26, 0.30866666666666664, 0.32466666666666666, 0.3526666666666667, 0.378]
pres1_all_pca_PasAgr = [0.22533333333333333, 0.24533333333333332, 0.234, 0.304, 0.30533333333333335, 0.31533333333333335, 0.34933333333333333]
pres1_all_pca_SGDCla = [0.224, 0.19333333333333333, 0.20066666666666666, 0.284, 0.2966666666666667, 0.3426666666666667, 0.37666666666666665]
pres1_all_pca_Percep = [0.19866666666666666, 0.19933333333333333, 0.0, 0.3006666666666667, 0.302, 0.32266666666666666, 0.33]

visualization(pres1_all_pca_LogReg,pres1_all_pca_PasAgr,pres1_all_pca_SGDCla,pres1_all_pca_Percep,
              "Precision 1 Scores All PCA Vs Training Data", "Precision1 (All PCA) Comparison LinearModel.png")

#Precision@3 Accuracy
pres3_all_pca_LogReg = [0.6086666666666667, 0.638, 0.66, 0.7026666666666667, 0.7233333333333334, 0.7646666666666667, 0.7786666666666666]
pres3_all_pca_PasAgr = [0.592, 0.638, 0.6246666666666667, 0.7, 0.7306666666666667, 0.7113333333333334, 0.7313333333333333]
pres3_all_pca_SGDCla = [0.5633333333333334, 0.532, 0.5466666666666666, 0.6646666666666666, 0.6966666666666667, 0.744, 0.7766666666666666]
pres3_all_pca_Percep = [0.5426666666666666, 0.5613333333333334, 0.0, 0.672, 0.71, 0.7226666666666667, 0.712]

visualization(pres3_all_pca_LogReg,pres3_all_pca_PasAgr,pres3_all_pca_SGDCla,pres3_all_pca_Percep,
              "Precision 3 Scores All PCA Vs Training Data", "Precision3 (All PCA) Comparison LinearModel.png")
