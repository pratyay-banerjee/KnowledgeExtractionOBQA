# %%
import matplotlib.pyplot as plt

# %%
# Validation Accuracy
GNB_val_acc = [0.4888, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
MNB_val_acc = [0.519, 0.5299, 0.5719, 0.5744, 0.5455, 0.5715, 0.5809]
BNB_val_acc = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
n_trainSamples = [100,500,1000,10000,20000,50000,75000]

# %%
def valAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,GNB_val_acc,label='Gaussian')
    ax.plot(n_trainSamples,MNB_val_acc,label='Multinomial')
    ax.plot(n_trainSamples,BNB_val_acc,label='Bernoulli')
    plt.title("Validation Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Validation_Accuracy_Comparision.png")
    #plt.show()

# %%
valAccuracyVisualization()

# %%
# Test Accuracy
GNB_test_acc = [0.4951, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]
MNB_test_acc = [0.5171, 0.531, 0.5683, 0.5751, 0.5424, 0.5787, 0.5785]
BNB_test_acc = [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5]

# %%
def testAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,GNB_test_acc,label='Gaussian')
    ax.plot(n_trainSamples,MNB_test_acc,label='Multinomial')
    ax.plot(n_trainSamples,BNB_test_acc,label='Bernoulli')
    plt.title("Test Accuracy Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_Test_Accuracy_Comparision.png")
    #plt.show()

# %%
testAccuracyVisualization()

# %%
mrrScore_GNB = [(0.2894759980759936, 0.0, 0.11533333333333333), (0.2857142857142808, 0.0, 0.0), (0.2857142857142808, 0.0, 0.0), (0.2857142857142808, 0.0, 0.0), (0.2857142857142808, 0.0, 0.0), (0.2898915343915296, 0.006, 0.007333333333333333), (0.2857142857142808, 0.0, 0.0)]
mrrScore_MNB = [(0.4916666666666686, 0.24866666666666667, 0.6433333333333333), (0.49063703703703787, 0.24466666666666667, 0.6466666666666666), (0.5071888888888902, 0.2693333333333333, 0.656), (0.5298222222222243, 0.282, 0.7113333333333334), (0.5268888888888907, 0.2826666666666667, 0.694), (0.5318666666666683, 0.28933333333333333, 0.7006666666666667), (0.5344666666666683, 0.294, 0.7026666666666667)]
mrrScore_BNB = [(0.2857142857142808, 0.0, 0.0), (0.3705212602212581, 0.07133333333333333, 0.45), (0.4038123617123601, 0.128, 0.4806666666666667), (0.43581216931217, 0.19933333333333333, 0.5213333333333333), (0.43551452621452685, 0.196, 0.5366666666666666), (0.4300578162578168, 0.18266666666666667, 0.544), (0.4318788359788366, 0.18466666666666667, 0.5533333333333333)]

mrr_GNB = []
mrr_MNB = []
mrr_BNB = []

p1_GNB = []
p1_MNB = []
p1_BNB = []

p3_GNB = []
p3_MNB = []
p3_BNB = []

for itm in mrrScore_GNB:
    mrr_GNB.append(itm[0])
    p1_GNB.append(itm[1])
    p3_GNB.append(itm[2])

for itm in mrrScore_MNB:
    mrr_MNB.append(itm[0])
    p1_MNB.append(itm[1])
    p3_MNB.append(itm[2])

for itm in mrrScore_BNB:
    mrr_BNB.append(itm[0])
    p1_BNB.append(itm[1])
    p3_BNB.append(itm[2])

# %%
# Mrr Comparision
def mrrAccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,mrr_GNB,label='Gaussian')
    ax.plot(n_trainSamples,mrr_MNB,label='Multinomial')
    ax.plot(n_trainSamples,mrr_BNB,label='Bernoulli')
    plt.title("Mrr Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_MRR_Scores_Comparision.png")
    #plt.show()

# %%
mrrAccuracyVisualization()

# %%
# PR@1 Comparision
def pr1AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p1_GNB,label='Gaussian')
    ax.plot(n_trainSamples,p1_MNB,label='Multinomial')
    ax.plot(n_trainSamples,p1_BNB,label='Bernoulli')
    plt.title("pr1 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_pr1_Scores_Comparision.png")
    #plt.show()

# %%
pr1AccuracyVisualization()

# %%
# PR@3 Comparision
def pr3AccuracyVisualization():
    ''' Plots the data points with the centroids
    '''
    fig = plt.figure()
    ax = plt.axes()
    ax.plot(n_trainSamples,p3_GNB,label='Gaussian')
    ax.plot(n_trainSamples,p3_MNB,label='Multinomial')
    ax.plot(n_trainSamples,p3_BNB,label='Bernoulli')
    plt.title("pr3 Scores vs TrainData")
    plt.legend()
    plt.xlabel("TrainData")
    plt.ylabel("Scores")
    fig.savefig("CLS_pr3_Scores_Comparision.png")
    #plt.show()

# %%
pr3AccuracyVisualization()
