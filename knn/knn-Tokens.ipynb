# %%
import xgboost as xbg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import pickle
import joblib

# %matplotlib inline

# %%
def load_cls(fname):
    return np.array(pickle.load(open(fname,"rb")))

# %%
X_train = load_cls("X_train_tokens.p")
X_val_cls = load_cls("X_val_tokens.p")

# %%
y_train = load_cls("y_train.p")
y_val = load_cls("y_val.p")

# %%
from sklearn.feature_extraction.text import CountVectorizer

def my_preprocessor(doc):
    return doc

# tokenize the doc and lemmatize its tokens
def my_tokenizer(doc):
    return doc

custom_vec = CountVectorizer(preprocessor=my_preprocessor, tokenizer=my_tokenizer)
cwm = custom_vec.fit_transform(X_train)
tokens = custom_vec.get_feature_names()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer,TfidfTransformer
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

# %%
feature_pipeline = Pipeline([
('vect',  CountVectorizer(min_df=.0025, max_df=0.25, ngram_range=(1,3),preprocessor=my_preprocessor, tokenizer=my_tokenizer)),
('tfidf', TfidfTransformer()),
])

# %%
X_train_f = feature_pipeline.fit_transform(X_train)
X_val_f =feature_pipeline.transform(X_val_cls)

# %%
model = XGBClassifier(n_jobs=-1,verbosity=2,n_estimators=300)
model.fit(X_train_f,y_train,verbose=True,eval_set=[(X_val_f,y_val)])
# Out:
# [0]	validation_0-error:0.448933
# [1]	validation_0-error:0.4486
# [2]	validation_0-error:0.4462
# [3]	validation_0-error:0.4446
# [4]	validation_0-error:0.443733
# [5]	validation_0-error:0.443333
# [6]	validation_0-error:0.4394
# [7]	validation_0-error:0.439467
# [8]	validation_0-error:0.438867
# [9]	validation_0-error:0.4392
# [10]	validation_0-error:0.438867
# [11]	validation_0-error:0.437867
# [12]	validation_0-error:0.437267
# [13]	validation_0-error:0.4292
# [14]	validation_0-error:0.43
# [15]	validation_0-error:0.427933
# [16]	validation_0-error:0.428533
# [17]	validation_0-error:0.428
# [18]	validation_0-error:0.428333
# [19]	validation_0-error:0.425733
# [20]	validation_0-error:0.421467
# [21]	validation_0-error:0.422667
# [22]	validation_0-error:0.422
# [23]	validation_0-error:0.421
# [24]	validation_0-error:0.422133
# [25]	validation_0-error:0.418667
# [26]	validation_0-error:0.418533
# [27]	validation_0-error:0.418533
# [28]	validation_0-error:0.4192
# [29]	validation_0-error:0.4186
# [30]	validation_0-error:0.419333
# [31]	validation_0-error:0.417133
# [32]	validation_0-error:0.416333
# [33]	validation_0-error:0.415333
# [34]	validation_0-error:0.415533
# [35]	validation_0-error:0.416133
# [36]	validation_0-error:0.415667
# [37]	validation_0-error:0.413533
# [38]	validation_0-error:0.412867
# [39]	validation_0-error:0.410933
# [40]	validation_0-error:0.410533
# [41]	validation_0-error:0.410333
# [42]	validation_0-error:0.409933
# [43]	validation_0-error:0.409067
# [44]	validation_0-error:0.408733
# [45]	validation_0-error:0.4086
# [46]	validation_0-error:0.4086
# [47]	validation_0-error:0.409067
# [48]	validation_0-error:0.409533
# [49]	validation_0-error:0.4092
# [50]	validation_0-error:0.4098
# [51]	validation_0-error:0.410533
# [52]	validation_0-error:0.410867
# [53]	validation_0-error:0.410667
# [54]	validation_0-error:0.4092
# [55]	validation_0-error:0.408067
# [56]	validation_0-error:0.4074
# [57]	validation_0-error:0.4056
# [58]	validation_0-error:0.405533
# [59]	validation_0-error:0.404933
# [60]	validation_0-error:0.404467
# [61]	validation_0-error:0.404533
# [62]	validation_0-error:0.404267
# [63]	validation_0-error:0.403733
# [64]	validation_0-error:0.404
# [65]	validation_0-error:0.403067
# [66]	validation_0-error:0.402867
# [67]	validation_0-error:0.401867
# [68]	validation_0-error:0.401133
# [69]	validation_0-error:0.401333
# [70]	validation_0-error:0.401333
# [71]	validation_0-error:0.401733
# [72]	validation_0-error:0.401
# [73]	validation_0-error:0.4008
# [74]	validation_0-error:0.401533
# [75]	validation_0-error:0.4006
# [76]	validation_0-error:0.400267
# [77]	validation_0-error:0.400667
# [78]	validation_0-error:0.4002
# [79]	validation_0-error:0.401533
# [80]	validation_0-error:0.4016
# [81]	validation_0-error:0.401267
# [82]	validation_0-error:0.401
# [83]	validation_0-error:0.399933
# [84]	validation_0-error:0.3998
# [85]	validation_0-error:0.4
# [86]	validation_0-error:0.399933
# [87]	validation_0-error:0.4
# [88]	validation_0-error:0.400333
# [89]	validation_0-error:0.4002
# [90]	validation_0-error:0.399533
# [91]	validation_0-error:0.399733
# [92]	validation_0-error:0.400933
# [93]	validation_0-error:0.400067
# [94]	validation_0-error:0.3998
# [95]	validation_0-error:0.397267
# [96]	validation_0-error:0.398133
# [97]	validation_0-error:0.396933
# [98]	validation_0-error:0.397533
# [99]	validation_0-error:0.397467
# [100]	validation_0-error:0.397067
# [101]	validation_0-error:0.397733
# [102]	validation_0-error:0.397933
# [103]	validation_0-error:0.3978
# [104]	validation_0-error:0.397867
# [105]	validation_0-error:0.397533
# [106]	validation_0-error:0.397
# [107]	validation_0-error:0.3966
# [108]	validation_0-error:0.396333
# [109]	validation_0-error:0.396533
# [110]	validation_0-error:0.395867
# [111]	validation_0-error:0.3956
# [112]	validation_0-error:0.3956
# [113]	validation_0-error:0.395733
# [114]	validation_0-error:0.395933
# [115]	validation_0-error:0.394333
# [116]	validation_0-error:0.394
# [117]	validation_0-error:0.3934
# [118]	validation_0-error:0.392467
# [119]	validation_0-error:0.391933
# [120]	validation_0-error:0.3916
# [121]	validation_0-error:0.391933
# [122]	validation_0-error:0.3924
# [123]	validation_0-error:0.3928
# [124]	validation_0-error:0.392333
# [125]	validation_0-error:0.392467
# [126]	validation_0-error:0.391333
# [127]	validation_0-error:0.392867
# [128]	validation_0-error:0.3926
# [129]	validation_0-error:0.3926
# [130]	validation_0-error:0.392467
# [131]	validation_0-error:0.3926
# [132]	validation_0-error:0.392
# [133]	validation_0-error:0.392333
# [134]	validation_0-error:0.392933
# [135]	validation_0-error:0.392467
# [136]	validation_0-error:0.392333
# [137]	validation_0-error:0.393867
# [138]	validation_0-error:0.393067
# [139]	validation_0-error:0.3928
# [140]	validation_0-error:0.393067
# [141]	validation_0-error:0.393133
# [142]	validation_0-error:0.392667
# [143]	validation_0-error:0.392867
# [144]	validation_0-error:0.392
# [145]	validation_0-error:0.392067
# [146]	validation_0-error:0.391867
# [147]	validation_0-error:0.391467
# [148]	validation_0-error:0.391933
# [149]	validation_0-error:0.392533
# [150]	validation_0-error:0.392
# [151]	validation_0-error:0.3914
# [152]	validation_0-error:0.391867
# [153]	validation_0-error:0.391267
# [154]	validation_0-error:0.391067
# [155]	validation_0-error:0.3908
# [156]	validation_0-error:0.390333
# [157]	validation_0-error:0.389533
# [158]	validation_0-error:0.3912
# [159]	validation_0-error:0.390733
# [160]	validation_0-error:0.391533
# [161]	validation_0-error:0.392933
# [162]	validation_0-error:0.393067
# [163]	validation_0-error:0.3932
# [164]	validation_0-error:0.393
# [165]	validation_0-error:0.393133
# [166]	validation_0-error:0.3926
# [167]	validation_0-error:0.3932
# [168]	validation_0-error:0.393133
# [169]	validation_0-error:0.392733
# [170]	validation_0-error:0.3924
# [171]	validation_0-error:0.3918
# [172]	validation_0-error:0.392067
# [173]	validation_0-error:0.392067
# [174]	validation_0-error:0.3928
# [175]	validation_0-error:0.392533
# [176]	validation_0-error:0.392133
# [177]	validation_0-error:0.3924
# [178]	validation_0-error:0.392133
# [179]	validation_0-error:0.391467
# [180]	validation_0-error:0.390267
# [181]	validation_0-error:0.391333
# [182]	validation_0-error:0.391
# [183]	validation_0-error:0.392267
# [184]	validation_0-error:0.392267
# [185]	validation_0-error:0.392133
# [186]	validation_0-error:0.392333
# [187]	validation_0-error:0.392133
# [188]	validation_0-error:0.391133
# [189]	validation_0-error:0.391067
# [190]	validation_0-error:0.3904
# [191]	validation_0-error:0.391267
# [192]	validation_0-error:0.390867
# [193]	validation_0-error:0.391133
# [194]	validation_0-error:0.3912
# [195]	validation_0-error:0.390667
# [196]	validation_0-error:0.390533
# [197]	validation_0-error:0.390467
# [198]	validation_0-error:0.390733
# [199]	validation_0-error:0.39
# [200]	validation_0-error:0.39
# [201]	validation_0-error:0.39
# [202]	validation_0-error:0.3904
# [203]	validation_0-error:0.3902
# [204]	validation_0-error:0.3898
# [205]	validation_0-error:0.3898
# [206]	validation_0-error:0.390867
# [207]	validation_0-error:0.390867
# [208]	validation_0-error:0.391333
# [209]	validation_0-error:0.390933
# [210]	validation_0-error:0.3914
# [211]	validation_0-error:0.391867
# [212]	validation_0-error:0.392467
# [213]	validation_0-error:0.3924
# [214]	validation_0-error:0.392467
# [215]	validation_0-error:0.392533
# [216]	validation_0-error:0.392333
# [217]	validation_0-error:0.392933
# [218]	validation_0-error:0.393467
# [219]	validation_0-error:0.3934
# [220]	validation_0-error:0.393267
# [221]	validation_0-error:0.392733
# [222]	validation_0-error:0.392667
# [223]	validation_0-error:0.392667
# [224]	validation_0-error:0.392533
# [225]	validation_0-error:0.3918
# [226]	validation_0-error:0.391733
# [227]	validation_0-error:0.391667
# [228]	validation_0-error:0.391733
# [229]	validation_0-error:0.393133
# [230]	validation_0-error:0.392667
# [231]	validation_0-error:0.3914
# [232]	validation_0-error:0.391733
# [233]	validation_0-error:0.3918
# [234]	validation_0-error:0.391933
# [235]	validation_0-error:0.391533
# [236]	validation_0-error:0.391
# [237]	validation_0-error:0.390533
# [238]	validation_0-error:0.389867
# [239]	validation_0-error:0.3898
# [240]	validation_0-error:0.3892
# [241]	validation_0-error:0.3906
# [242]	validation_0-error:0.389867
# [243]	validation_0-error:0.389333
# [244]	validation_0-error:0.389267
# [245]	validation_0-error:0.388867
# [246]	validation_0-error:0.3888
# [247]	validation_0-error:0.389133
# [248]	validation_0-error:0.389267
# [249]	validation_0-error:0.3886
# [250]	validation_0-error:0.389
# [251]	validation_0-error:0.389733
# [252]	validation_0-error:0.389267
# [253]	validation_0-error:0.389267
# [254]	validation_0-error:0.388933
# [255]	validation_0-error:0.389067
# [256]	validation_0-error:0.389667
# [257]	validation_0-error:0.3902
# [258]	validation_0-error:0.390333
# [259]	validation_0-error:0.390867
# [260]	validation_0-error:0.390867
# [261]	validation_0-error:0.3906
# [262]	validation_0-error:0.389333
# [263]	validation_0-error:0.39
# [264]	validation_0-error:0.389933
# [265]	validation_0-error:0.389467
# [266]	validation_0-error:0.3896
# [267]	validation_0-error:0.3892
# [268]	validation_0-error:0.389133
# [269]	validation_0-error:0.388933
# [270]	validation_0-error:0.389467
# [271]	validation_0-error:0.3894
# [272]	validation_0-error:0.3894
# [273]	validation_0-error:0.3892
# [274]	validation_0-error:0.389467
# [275]	validation_0-error:0.3898
# [276]	validation_0-error:0.390067
# [277]	validation_0-error:0.390467
# [278]	validation_0-error:0.389267
# [279]	validation_0-error:0.3906
# [280]	validation_0-error:0.390267
# [281]	validation_0-error:0.390667
# [282]	validation_0-error:0.3906
# [283]	validation_0-error:0.3908
# [284]	validation_0-error:0.3908
# [285]	validation_0-error:0.3904
# [286]	validation_0-error:0.3904
# [287]	validation_0-error:0.3904
# [288]	validation_0-error:0.390333
# [289]	validation_0-error:0.389067
# [290]	validation_0-error:0.389067
# [291]	validation_0-error:0.389733
# [292]	validation_0-error:0.3904
# [293]	validation_0-error:0.3904
# [294]	validation_0-error:0.390133
# [295]	validation_0-error:0.389933
# [296]	validation_0-error:0.3908
# [297]	validation_0-error:0.390467
# [298]	validation_0-error:0.390733
# [299]	validation_0-error:0.3908
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=300,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=None, silent=True, subsample=1, verbosity=2)

# %%
from sklearn.metrics import accuracy_score
preds_val = model.predict(X_val_f)
accuracy = accuracy_score(y_val, preds_val)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 60.92%

# %%
X_test = load_cls("X_test_tokens.p")
y_test = load_cls("y_test.p")

# %%
X_test_f =feature_pipeline.transform(X_test)

# %%
preds_test = model.predict(X_test_f)
accuracy = accuracy_score(y_test, preds_test)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 59.37%

# %%
from scipy.stats import rankdata

def mrrs(out, labels):
#     print(out,labels)
    outputs = np.argmax(out,axis=1)
    mrr = 0.0 
    for label,ranks in zip(labels,out):
        ranks = rankdata(ranks*-1)
        rank = ranks[label]
#         print(rank,ranks)
        mrr+=1/rank
    return mrr/len(labels)

def mrrwrapper(qid2c,qid2indexmap,preds_prob):
    labels = []
    out = []
    for qid in qid2c.keys():
        scores = []
        for ix in qid2indexmap[qid]:
            if len(scores) < 6:
                scores.append(preds_prob[ix][1])
        if len(scores) < 6:
            continue
        out.append(scores)
        labels.append(int(qid2c[qid]))
    return mrrs(np.array(out),labels)

def load_ranking(fname):
    return pickle.load(open("ranking_"+fname+".p","rb"))

# %%
preds_test_probs = model.predict_proba(X_test_f)

# %%
qid2c,qid2indexmap = load_ranking("test")

# %%
mrrwrapper(qid2c,qid2indexmap,preds_test_probs)
# Out:
# 0.5230778739778764
